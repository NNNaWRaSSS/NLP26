# %%
import nltk
nltk.download('wordnet')

from nltk.corpus import wordnet as wn
sorted(wn.langs())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['eng']

# %%
wn.synset('fly.v.01').lemma_names()
# Out:
# ['fly', 'wing']

# %%
wn.synset('fly.n.01').definition()
# Out:
# 'two-winged insects characterized by active flight'

# %%
wn.synset('car.n.01').examples()
# Out:
# ['he needs a car to get to work']

# %%
wn.synset('car.n.01').lemmas()
# Out:
# [Lemma('car.n.01.car'),
#  Lemma('car.n.01.auto'),
#  Lemma('car.n.01.automobile'),
#  Lemma('car.n.01.machine'),
#  Lemma('car.n.01.motorcar')]

# %%
for synset in wn.synsets('fly'):
    print(synset.lemma_names())
# Out:
# ['fly']
# ['tent-fly', 'rainfly', 'fly_sheet', 'fly', 'tent_flap']
# ['fly', 'fly_front']
# ['fly', 'fly_ball']
# ['fly']
# ['fly', 'wing']
# ['fly']
# ['fly', 'aviate', 'pilot']
# ['fly']
# ['fly']
# ['fly']
# ['fly']
# ['fly', 'fell', 'vanish']
# ['fly']
# ['fly']
# ['flee', 'fly', 'take_flight']
# ['fly']
# ['fly']
# ['vanish', 'fly', 'vaporize']
# ['fly']

# %%
synset = wn.synsets("flower")
for syns in synset:
    for word in syns.lemmas():
        if word.antonyms():
            print(word.antonyms())

# %%
sorted(wn.langs())

# %%
from nltk.corpus import wordnet
py_arr = wordnet.synsets("python")
print (py_arr[0].name())
print (py_arr[0].lemmas()[0].name())
print (py_arr[0].definition())
print (py_arr[0].examples())

# %%
>>> dog = wn.synset('dog.n.01')

>>> dog.hypernyms()
# Out:
# [Synset('domestic_animal.n.01'), Synset('canine.n.02')]

# %%
w1 = wn.synset('ship.n.01')
w2 = wn.synset('boat.n.01')
print(w1.path_similarity(w2))
# Out:
# 0.3333333333333333

# %%
w1 = wn.synset('ship.n.01')
w2 = wn.synset('cat.n.01')
print(w1.wup_similarity(w2))
# Out:
# 0.32

# %%
>>> dog.hyponyms()
# Out:
# [Synset('hunting_dog.n.01'),
#  Synset('poodle.n.01'),
#  Synset('mexican_hairless.n.01'),
#  Synset('puppy.n.01'),
#  Synset('leonberg.n.01'),
#  Synset('newfoundland.n.01'),
#  Synset('corgi.n.01'),
#  Synset('dalmatian.n.02'),
#  Synset('cur.n.01'),
#  Synset('pooch.n.01'),
#  Synset('lapdog.n.01'),
#  Synset('pug.n.01'),
#  Synset('griffon.n.02'),
#  Synset('spitz.n.01'),
#  Synset('toy_dog.n.01'),
#  Synset('basenji.n.01'),
#  Synset('great_pyrenees.n.01'),
#  Synset('working_dog.n.01')]

# %%
w1 = wn.synset('dog.n.01')
w2 = wn.synset('cat.n.01')
w1.path_similarity(w2)
# Out:
# 0.2

# %%
>>> dog.member_holonyms()
# Out:
# [Synset('pack.n.06'), Synset('canis.n.01')]

# %%
w1 = wn.synset('ship.n.01')
w2 = wn.synset('boat.n.01')
print(w1.path_similarity(w2))
# Out:
# 0.3333333333333333

# %%
>>> dog.root_hypernyms()
# Out:
# [Synset('entity.n.01')]

# %%
print ("Hypernym for 'fish': ", wn.synset('fish.n.01').hyponyms())
# Out:
# Hypernym for 'fish':  [Synset('rough_fish.n.01'), Synset('young_fish.n.01'), Synset('game_fish.n.01'), Synset('bottom-feeder.n.02'), Synset('spawner.n.01'), Synset('cartilaginous_fish.n.01'), Synset('climbing_perch.n.01'), Synset('fingerling.n.01'), Synset('food_fish.n.01'), Synset('bony_fish.n.01'), Synset('northern_snakehead.n.01'), Synset('bottom_lurkers.n.01'), Synset('mouthbreeder.n.01')]

# %%
>>> wn.synset('dog.n.01').lowest_common_hypernyms(wn.synset('cat.n.01'))
# Out:
# [Synset('carnivore.n.01')]
